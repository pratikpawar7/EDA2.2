# %% [markdown]
# # Google play store data

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
df.to_csv('google_playstore.csv')

# %%
'''
Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
the dataset have?
'''

df.shape
# Out:
# (10841, 13)

# %% [markdown]
# ### IT has the 10841 rows and 13 columns

# %%
'''
Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
app categories.
'''
plt.figure(figsize = (9 , 15 ))
sns.boxplot(data= df , y=df['Category'] , x = df['Rating'] )
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Category'>

# %%
'''

Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
impact your analysis.
'''

df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ## There is the 1474 missing values in teh rating column

# %%
'''
Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
the relationship.
'''
sns.scatterplot(data = df ,  x  = )

# %%
df['Size'] = df['Size'].str.replace('M' , '000')

# %%
df['Size'] = df['Size'].str.replace('k' , '')

# %%
df['Size'] = df['Size'].str.replace('+' , '')
df['Size'] = df['Size'].str.replace(',' , '')
# Out:
# /tmp/ipykernel_3710/617482967.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Size'] = df['Size'].str.replace('+' , '')

# %%
df['Size'] = df['Size'].astype(float)

# %%
len(df['Rating'])
# Out:
# 10841

# %%
sns.scatterplot(data = df , x = df['Size'] , y = df['Rating'])
# Out:
# <AxesSubplot: xlabel='Size', ylabel='Rating'>

# %%
'''
Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.
'''
#sns.boxplot(data = df , x = df['Price'] , y =df['Type'])
# Out:
# '\nQ13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.\n'

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
df1['Type'].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df1['Type'] = df1['Type'].replace({
    'Free': 0,
    'Paid': 1,
    np.nan: 0,
    '0': 0
})

# Convert the column to integer type
df1['Type'] = df1['Type'].astype(int)

# %%
sns.barplot(data = df1 , y= df1['Type'] , x = df1['Price'])
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Type'>

# %%
'''
Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
with the highest number of installs.
'''
sorted_df = df.sort_values(by='Rating', ascending=False)

# Select the top 10 apps
top_10_apps = sorted_df.head(10)

print(top_10_apps)
# Out:
#                                            App  Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame       1.9    19.0    3.0M
# 9511                  Ek Bander Ne Kholi Dukan    FAMILY     5.0      10
# 10166                     FA Player Essentials    SPORTS     5.0       7
# 7895                Dine In CT - Food Delivery  SHOPPING     5.0       4
# 5118                          Eternal Light AG    SOCIAL     5.0      30
# 6953            BxPort - Bitcoin Bx (Thailand)   FINANCE     5.0       4
# 5125                     Ag Valley Cooperative  BUSINESS     5.0       6
# 7896                               CT Checkout   FINANCE     5.0       1
# 5139                              Chenoweth AH   MEDICAL     5.0       1
# 5145                          Arrowhead AH App   MEDICAL     5.0       3
#
#                Size Installs  Type     Price Content Rating  \
# 10472  1.111010e+10     Free     0  Everyone            NaN
# ...

# %%
# Out:
# 16.0
